# %%
import json
import numpy as np
import pandas as pd

# %%
data_path = "/Users/yuchen.zhang/Documents/Projects/domain-adaptation-nlp/outputs/"

# %%
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1.json" ,"r") as f:
    no_fs = json.load(f)
    
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1_fs_least.json" ,"r") as f:
    fs_least = json.load(f)
    
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1_fs_random.json" ,"r") as f:
    fs_random = json.load(f)

# %%
no_fs_df = pd.DataFrame.from_dict(no_fs)
fs_least_df = pd.DataFrame.from_dict(fs_least)
fs_random_df = pd.DataFrame.from_dict(fs_random)

# %%
no_fs_df
# Out:
#                     Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# s2s                                                            0.930
# t2t                                                            0.930
# s2t                                                            0.930
# self_train                                                     0.930
# gradual_self_train                                             0.926
# num_iter                                                      12.000
#
#                     Home_and_Kitchen.train_to_Movies_and_TV.train  \
# s2s                                                        0.9300
# t2t                                                        0.9265
# s2t                                                        0.8780
# self_train                                                 0.8770
# gradual_self_train                                         0.9035
# num_iter                                                  13.0000
#
#                     Home_and_Kitchen.train_to_Electronics.train  \
# s2s                                                      0.9300
# t2t                                                      0.9150
# s2t                                                      0.8870
# self_train                                               0.8850
# gradual_self_train                                       0.8985
# num_iter                                                14.0000
#
#                     Home_and_Kitchen.train_to_Books.train  \
# s2s                                                0.9300
# t2t                                                0.9415
# s2t                                                0.8965
# self_train                                         0.9040
# gradual_self_train                                 0.9140
# num_iter                                          13.0000
#
#                     Movies_and_TV.train_to_Home_and_Kitchen.train  \
# s2s                                                        0.9265
# t2t                                                        0.9300
# s2t                                                        0.8680
# self_train                                                 0.8725
# gradual_self_train                                         0.8905
# num_iter                                                  14.0000
#
#                     Movies_and_TV.train_to_Movies_and_TV.train  \
# s2s                                                     0.9265
# t2t                                                     0.9265
# s2t                                                     0.9265
# self_train                                              0.9260
# gradual_self_train                                      0.9255
# num_iter                                               12.0000
#
#                     Movies_and_TV.train_to_Electronics.train  \
# s2s                                                   0.9265
# t2t                                                   0.9150
# s2t                                                   0.8155
# self_train                                            0.8100
# gradual_self_train                                    0.8905
# num_iter                                             13.0000
#
#                     Movies_and_TV.train_to_Books.train  \
# s2s                                             0.9265
# t2t                                             0.9415
# s2t                                             0.9165
# self_train                                      0.9190
# gradual_self_train                              0.9235
# num_iter                                       15.0000
#
#                     Electronics.train_to_Home_and_Kitchen.train  \
# s2s                                                       0.915
# t2t                                                       0.930
# s2t                                                       0.917
# self_train                                                0.918
# gradual_self_train                                        0.914
# num_iter                                                 13.000
#
#                     Electronics.train_to_Movies_and_TV.train  \
# s2s                                                   0.9150
# t2t                                                   0.9265
# s2t                                                   0.9020
# self_train                                            0.9065
# gradual_self_train                                    0.9100
# num_iter                                             13.0000
#
#                     Electronics.train_to_Electronics.train  \
# s2s                                                 0.9150
# t2t                                                 0.9150
# s2t                                                 0.9150
# self_train                                          0.9155
# gradual_self_train                                  0.9105
# num_iter                                           12.0000
#
#                     Electronics.train_to_Books.train  \
# s2s                                           0.9150
# t2t                                           0.9415
# s2t                                           0.8925
# self_train                                    0.9005
# gradual_self_train                            0.9195
# num_iter                                     13.0000
#
#                     Books.train_to_Home_and_Kitchen.train  \
# s2s                                                0.9415
# t2t                                                0.9300
# s2t                                                0.8480
# self_train                                         0.8495
# gradual_self_train                                 0.8875
# num_iter                                          14.0000
#
#                     Books.train_to_Movies_and_TV.train  \
# s2s                                             0.9415
# t2t                                             0.9265
# s2t                                             0.9020
# self_train                                      0.9035
# gradual_self_train                              0.9115
# num_iter                                       15.0000
#
#                     Books.train_to_Electronics.train  \
# s2s                                           0.9415
# t2t                                           0.9150
# s2t                                           0.8045
# self_train                                    0.8055
# gradual_self_train                            0.8785
# num_iter                                     18.0000
#
#                     Books.train_to_Books.train
# s2s                                     0.9415
# t2t                                     0.9415
# s2t                                     0.9415
# self_train                              0.9415
# gradual_self_train                      0.9395
# num_iter                               12.0000

# %%
fs_least_df
# Out:
#                        Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# fs_same_index                                                  0.930045
# fs_random_index                                                0.931555
# fs_least_index                                                 0.934071
# fs_gradual_self_train                                          0.926522
# num_iter                                                      13.000000
#
#                        Home_and_Kitchen.train_to_Movies_and_TV.train  \
# fs_same_index                                               0.901359
# fs_random_index                                             0.889784
# fs_least_index                                              0.897836
# fs_gradual_self_train                                       0.904882
# num_iter                                                   13.000000
#
#                        Home_and_Kitchen.train_to_Electronics.train  \
# fs_same_index                                             0.887714
# fs_random_index                                           0.885196
# fs_least_index                                            0.889225
# fs_gradual_self_train                                     0.896274
# num_iter                                                 14.000000
#
#                        Home_and_Kitchen.train_to_Books.train  \
# fs_same_index                                       0.898339
# fs_random_index                                     0.896326
# fs_least_index                                      0.893306
# fs_gradual_self_train                               0.914444
# num_iter                                           13.000000
#
#                        Movies_and_TV.train_to_Home_and_Kitchen.train  \
# fs_same_index                                               0.884635
# fs_random_index                                             0.883123
# fs_least_index                                              0.881612
# fs_gradual_self_train                                       0.890176
# num_iter                                                   15.000000
#
#                        Movies_and_TV.train_to_Movies_and_TV.train  \
# fs_same_index                                            0.926019
# fs_random_index                                          0.927026
# fs_least_index                                           0.928535
# fs_gradual_self_train                                    0.925013
# num_iter                                                13.000000
#
#                        Movies_and_TV.train_to_Electronics.train  \
# fs_same_index                                          0.847509
# fs_random_index                                        0.834424
# fs_least_index                                         0.857071
# fs_gradual_self_train                                  0.890287
# num_iter                                              13.000000
#
#                        Movies_and_TV.train_to_Books.train  \
# fs_same_index                                    0.914819
# fs_random_index                                  0.918347
# fs_least_index                                   0.926915
# fs_gradual_self_train                            0.922883
# num_iter                                        16.000000
#
#                        Electronics.train_to_Home_and_Kitchen.train  \
# fs_same_index                                             0.916415
# fs_random_index                                           0.920947
# fs_least_index                                            0.918933
# fs_gradual_self_train                                     0.915911
# num_iter                                                 14.000000
#
#                        Electronics.train_to_Movies_and_TV.train  \
# fs_same_index                                          0.900756
# fs_random_index                                        0.899143
# fs_least_index                                         0.902673
# fs_gradual_self_train                                  0.908816
# num_iter                                              17.000000
#
#                        Electronics.train_to_Electronics.train  \
# fs_same_index                                        0.914444
# fs_random_index                                      0.914444
# fs_least_index                                       0.915954
# fs_gradual_self_train                                0.910418
# num_iter                                            13.000000
#
#                        Electronics.train_to_Books.train  \
# fs_same_index                                  0.885254
# fs_random_index                                0.899346
# fs_least_index                                 0.902869
# fs_gradual_self_train                          0.919980
# num_iter                                      13.000000
#
#                        Books.train_to_Home_and_Kitchen.train  \
# fs_same_index                                       0.873615
# fs_random_index                                     0.843404
# fs_least_index                                      0.868077
# fs_gradual_self_train                               0.887714
# num_iter                                           14.000000
#
#                        Books.train_to_Movies_and_TV.train  \
# fs_same_index                                    0.905290
# fs_random_index                                  0.906801
# fs_least_index                                   0.913350
# fs_gradual_self_train                            0.911839
# num_iter                                        15.000000
#
#                        Books.train_to_Electronics.train  \
# fs_same_index                                  0.860747
# fs_random_index                                0.846620
# fs_least_index                                 0.868315
# fs_gradual_self_train                          0.877901
# num_iter                                      18.000000
#
#                        Books.train_to_Books.train
# fs_same_index                            0.941147
# fs_random_index                          0.941147
# fs_least_index                           0.943159
# fs_gradual_self_train                    0.939638
# num_iter                                12.000000

# %%
fs_random_df
# Out:
#                        Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# fs_same_index                                                  0.930080
# fs_random_index                                                0.930080
# fs_least_index                                                 0.933602
# fs_gradual_self_train                                          0.926056
# num_iter                                                      12.000000
#
#                        Home_and_Kitchen.train_to_Movies_and_TV.train  \
# fs_same_index                                               0.903372
# fs_random_index                                             0.889728
# fs_least_index                                              0.894763
# fs_gradual_self_train                                       0.906392
# num_iter                                                   14.000000
#
#                        Home_and_Kitchen.train_to_Electronics.train  \
# fs_same_index                                             0.886261
# fs_random_index                                           0.888721
# fs_least_index                                            0.889225
# fs_gradual_self_train                                     0.896829
# num_iter                                                 14.000000
#
#                        Home_and_Kitchen.train_to_Books.train  \
# fs_same_index                                       0.895823
# fs_random_index                                     0.897333
# fs_least_index                                      0.893306
# fs_gradual_self_train                               0.916457
# num_iter                                           13.000000
#
#                        Movies_and_TV.train_to_Home_and_Kitchen.train  \
# fs_same_index                                               0.879658
# fs_random_index                                             0.881672
# fs_least_index                                              0.883686
# fs_gradual_self_train                                       0.893756
# num_iter                                                   14.000000
#
#                        Movies_and_TV.train_to_Movies_and_TV.train  \
# fs_same_index                                            0.927026
# fs_random_index                                          0.925516
# fs_least_index                                           0.928535
# fs_gradual_self_train                                    0.926522
# num_iter                                                13.000000
#
#                        Movies_and_TV.train_to_Electronics.train  \
# fs_same_index                                          0.853045
# fs_random_index                                        0.852971
# fs_least_index                                         0.849950
# fs_gradual_self_train                                  0.889280
# num_iter                                              14.000000
#
#                        Movies_and_TV.train_to_Books.train  \
# fs_same_index                                    0.913306
# fs_random_index                                  0.924899
# fs_least_index                                   0.926915
# fs_gradual_self_train                            0.923387
# num_iter                                        16.000000
#
#                        Electronics.train_to_Home_and_Kitchen.train  \
# fs_same_index                                             0.914947
# fs_random_index                                           0.918429
# fs_least_index                                            0.918933
# fs_gradual_self_train                                     0.913941
# num_iter                                                 14.000000
#
#                        Electronics.train_to_Movies_and_TV.train  \
# fs_same_index                                          0.893756
# fs_random_index                                        0.901210
# fs_least_index                                         0.898690
# fs_gradual_self_train                                  0.910876
# num_iter                                              16.000000
#
#                        Electronics.train_to_Electronics.train  \
# fs_same_index                                        0.914487
# fs_random_index                                      0.915996
# fs_least_index                                       0.916499
# fs_gradual_self_train                                0.910966
# num_iter                                            12.000000
#
#                        Electronics.train_to_Books.train  \
# fs_same_index                                  0.889280
# fs_random_index                                0.902869
# fs_least_index                                 0.902869
# fs_gradual_self_train                          0.919477
# num_iter                                      13.000000
#
#                        Books.train_to_Home_and_Kitchen.train  \
# fs_same_index                                       0.870025
# fs_random_index                                     0.858438
# fs_least_index                                      0.869521
# fs_gradual_self_train                               0.890680
# num_iter                                           15.000000
#
#                        Books.train_to_Movies_and_TV.train  \
# fs_same_index                                    0.910327
# fs_random_index                                  0.900706
# fs_least_index                                   0.913306
# fs_gradual_self_train                            0.914358
# num_iter                                        16.000000
#
#                        Books.train_to_Electronics.train  \
# fs_same_index                                  0.835934
# fs_random_index                                0.828384
# fs_least_index                                 0.862607
# fs_gradual_self_train                          0.883241
# num_iter                                      13.000000
#
#                        Books.train_to_Books.train
# fs_same_index                            0.941147
# fs_random_index                          0.940141
# fs_least_index                           0.943159
# fs_gradual_self_train                    0.939135
# num_iter                                12.000000

# %%
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1.json" ,"r") as f:
    no_fs = json.load(f)
    
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1_fs_least.json" ,"r") as f:
    fs_least = json.load(f)
    
with open (data_path + "accuracies_ti_amazon_conf_blc_c0.1_fs_random.json" ,"r") as f:
    fs_random = json.load(f)

# %%
no_fs_df = pd.DataFrame.from_dict(no_fs)
fs_least_df = pd.DataFrame.from_dict(fs_least)
fs_random_df = pd.DataFrame.from_dict(fs_random)

# %%
no_fs_df
# Out:
#                     Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# s2s                                                           0.9300
# t2t                                                           0.9300
# s2t                                                           0.9300
# self_train                                                    0.9300
# gradual_self_train                                            0.9255
# num_iter                                                     12.0000
#
#                     Home_and_Kitchen.train_to_Movies_and_TV.train  \
# s2s                                                        0.9300
# t2t                                                        0.9265
# s2t                                                        0.8780
# self_train                                                 0.8770
# gradual_self_train                                         0.9035
# num_iter                                                  13.0000
#
#                     Home_and_Kitchen.train_to_Electronics.train  \
# s2s                                                      0.9300
# t2t                                                      0.9150
# s2t                                                      0.8870
# self_train                                               0.8850
# gradual_self_train                                       0.8995
# num_iter                                                14.0000
#
#                     Home_and_Kitchen.train_to_Books.train  \
# s2s                                                0.9300
# t2t                                                0.9415
# s2t                                                0.8965
# self_train                                         0.9040
# gradual_self_train                                 0.9145
# num_iter                                          13.0000
#
#                     Movies_and_TV.train_to_Home_and_Kitchen.train  \
# s2s                                                        0.9265
# t2t                                                        0.9300
# s2t                                                        0.8680
# self_train                                                 0.8725
# gradual_self_train                                         0.8920
# num_iter                                                  14.0000
#
#                     Movies_and_TV.train_to_Movies_and_TV.train  \
# s2s                                                     0.9265
# t2t                                                     0.9265
# s2t                                                     0.9265
# self_train                                              0.9260
# gradual_self_train                                      0.9265
# num_iter                                               12.0000
#
#                     Movies_and_TV.train_to_Electronics.train  \
# s2s                                                   0.9265
# t2t                                                   0.9150
# s2t                                                   0.8155
# self_train                                            0.8100
# gradual_self_train                                    0.8905
# num_iter                                             13.0000
#
#                     Movies_and_TV.train_to_Books.train  \
# s2s                                             0.9265
# t2t                                             0.9415
# s2t                                             0.9165
# self_train                                      0.9190
# gradual_self_train                              0.9230
# num_iter                                       15.0000
#
#                     Electronics.train_to_Home_and_Kitchen.train  \
# s2s                                                       0.915
# t2t                                                       0.930
# s2t                                                       0.917
# self_train                                                0.918
# gradual_self_train                                        0.915
# num_iter                                                 13.000
#
#                     Electronics.train_to_Movies_and_TV.train  \
# s2s                                                   0.9150
# t2t                                                   0.9265
# s2t                                                   0.9020
# self_train                                            0.9065
# gradual_self_train                                    0.9100
# num_iter                                             13.0000
#
#                     Electronics.train_to_Electronics.train  \
# s2s                                                 0.9150
# t2t                                                 0.9150
# s2t                                                 0.9150
# self_train                                          0.9155
# gradual_self_train                                  0.9105
# num_iter                                           12.0000
#
#                     Electronics.train_to_Books.train  \
# s2s                                           0.9150
# t2t                                           0.9415
# s2t                                           0.8925
# self_train                                    0.9005
# gradual_self_train                            0.9185
# num_iter                                     13.0000
#
#                     Books.train_to_Home_and_Kitchen.train  \
# s2s                                                0.9415
# t2t                                                0.9300
# s2t                                                0.8480
# self_train                                         0.8495
# gradual_self_train                                 0.8885
# num_iter                                          14.0000
#
#                     Books.train_to_Movies_and_TV.train  \
# s2s                                             0.9415
# t2t                                             0.9265
# s2t                                             0.9020
# self_train                                      0.9035
# gradual_self_train                              0.9130
# num_iter                                       15.0000
#
#                     Books.train_to_Electronics.train  \
# s2s                                           0.9415
# t2t                                           0.9150
# s2t                                           0.8045
# self_train                                    0.8055
# gradual_self_train                            0.8790
# num_iter                                     18.0000
#
#                     Books.train_to_Books.train
# s2s                                     0.9415
# t2t                                     0.9415
# s2t                                     0.9415
# self_train                              0.9415
# gradual_self_train                      0.9400
# num_iter                               12.0000

# %%
fs_least_df
# Out:
#                        Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# fs_same_index                                                  0.930045
# fs_random_index                                                0.929542
# fs_least_index                                                 0.934071
# fs_gradual_self_train                                          0.926522
# num_iter                                                      13.000000
#
#                        Home_and_Kitchen.train_to_Movies_and_TV.train  \
# fs_same_index                                               0.901359
# fs_random_index                                             0.881731
# fs_least_index                                              0.897836
# fs_gradual_self_train                                       0.904882
# num_iter                                                   13.000000
#
#                        Home_and_Kitchen.train_to_Electronics.train  \
# fs_same_index                                             0.887714
# fs_random_index                                           0.885700
# fs_least_index                                            0.889225
# fs_gradual_self_train                                     0.896274
# num_iter                                                 14.000000
#
#                        Home_and_Kitchen.train_to_Books.train  \
# fs_same_index                                       0.898339
# fs_random_index                                     0.894313
# fs_least_index                                      0.893306
# fs_gradual_self_train                               0.913941
# num_iter                                           13.000000
#
#                        Movies_and_TV.train_to_Home_and_Kitchen.train  \
# fs_same_index                                               0.884635
# fs_random_index                                             0.876071
# fs_least_index                                              0.881612
# fs_gradual_self_train                                       0.891688
# num_iter                                                   15.000000
#
#                        Movies_and_TV.train_to_Movies_and_TV.train  \
# fs_same_index                                            0.926019
# fs_random_index                                          0.925516
# fs_least_index                                           0.928535
# fs_gradual_self_train                                    0.925516
# num_iter                                                13.000000
#
#                        Movies_and_TV.train_to_Electronics.train  \
# fs_same_index                                          0.847509
# fs_random_index                                        0.826875
# fs_least_index                                         0.857071
# fs_gradual_self_train                                  0.889280
# num_iter                                              13.000000
#
#                        Movies_and_TV.train_to_Books.train  \
# fs_same_index                                    0.914819
# fs_random_index                                  0.918851
# fs_least_index                                   0.926915
# fs_gradual_self_train                            0.922883
# num_iter                                        16.000000
#
#                        Electronics.train_to_Home_and_Kitchen.train  \
# fs_same_index                                             0.916415
# fs_random_index                                           0.917422
# fs_least_index                                            0.918933
# fs_gradual_self_train                                     0.916415
# num_iter                                                 14.000000
#
#                        Electronics.train_to_Movies_and_TV.train  \
# fs_same_index                                          0.900756
# fs_random_index                                        0.901160
# fs_least_index                                         0.902673
# fs_gradual_self_train                                  0.909320
# num_iter                                              17.000000
#
#                        Electronics.train_to_Electronics.train  \
# fs_same_index                                        0.914444
# fs_random_index                                      0.914947
# fs_least_index                                       0.915954
# fs_gradual_self_train                                0.910418
# num_iter                                            13.000000
#
#                        Electronics.train_to_Books.train  \
# fs_same_index                                  0.885254
# fs_random_index                                0.893810
# fs_least_index                                 0.902869
# fs_gradual_self_train                          0.918973
# num_iter                                      13.000000
#
#                        Books.train_to_Home_and_Kitchen.train  \
# fs_same_index                                       0.873615
# fs_random_index                                     0.866566
# fs_least_index                                      0.868077
# fs_gradual_self_train                               0.889225
# num_iter                                           14.000000
#
#                        Books.train_to_Movies_and_TV.train  \
# fs_same_index                                    0.905290
# fs_random_index                                  0.903275
# fs_least_index                                   0.913350
# fs_gradual_self_train                            0.911335
# num_iter                                        15.000000
#
#                        Books.train_to_Electronics.train  \
# fs_same_index                                  0.860747
# fs_random_index                                0.832997
# fs_least_index                                 0.868315
# fs_gradual_self_train                          0.877901
# num_iter                                      18.000000
#
#                        Books.train_to_Books.train
# fs_same_index                            0.941147
# fs_random_index                          0.940644
# fs_least_index                           0.943159
# fs_gradual_self_train                    0.940141
# num_iter                                12.000000

# %%
fs_random_df
# Out:
#                        Home_and_Kitchen.train_to_Home_and_Kitchen.train  \
# fs_same_index                                                  0.928571
# fs_random_index                                                0.930080
# fs_least_index                                                 0.933602
# fs_gradual_self_train                                          0.926056
# num_iter                                                      12.000000
#
#                        Home_and_Kitchen.train_to_Movies_and_TV.train  \
# fs_same_index                                               0.897784
# fs_random_index                                             0.890176
# fs_least_index                                              0.896222
# fs_gradual_self_train                                       0.902820
# num_iter                                                   15.000000
#
#                        Home_and_Kitchen.train_to_Electronics.train  \
# fs_same_index                                             0.887714
# fs_random_index                                           0.888721
# fs_least_index                                            0.889225
# fs_gradual_self_train                                     0.898792
# num_iter                                                 14.000000
#
#                        Home_and_Kitchen.train_to_Books.train  \
# fs_same_index                                       0.897281
# fs_random_index                                     0.895214
# fs_least_index                                      0.894207
# fs_gradual_self_train                               0.915408
# num_iter                                           15.000000
#
#                        Movies_and_TV.train_to_Home_and_Kitchen.train  \
# fs_same_index                                               0.883182
# fs_random_index                                             0.884189
# fs_least_index                                              0.883686
# fs_gradual_self_train                                       0.891742
# num_iter                                                   14.000000
#
#                        Movies_and_TV.train_to_Movies_and_TV.train  \
# fs_same_index                                            0.926056
# fs_random_index                                          0.925553
# fs_least_index                                           0.928068
# fs_gradual_self_train                                    0.926056
# num_iter                                                12.000000
#
#                        Movies_and_TV.train_to_Electronics.train  \
# fs_same_index                                          0.864484
# fs_random_index                                        0.842821
# fs_least_index                                         0.857431
# fs_gradual_self_train                                  0.890176
# num_iter                                              15.000000
#
#                        Movies_and_TV.train_to_Books.train  \
# fs_same_index                                    0.915493
# fs_random_index                                  0.919980
# fs_least_index                                   0.926522
# fs_gradual_self_train                            0.922535
# num_iter                                        13.000000
#
#                        Electronics.train_to_Home_and_Kitchen.train  \
# fs_same_index                                             0.915869
# fs_random_index                                           0.918851
# fs_least_index                                            0.919859
# fs_gradual_self_train                                     0.915365
# num_iter                                                 16.000000
#
#                        Electronics.train_to_Movies_and_TV.train  \
# fs_same_index                                          0.904786
# fs_random_index                                        0.902218
# fs_least_index                                         0.898690
# fs_gradual_self_train                                  0.912343
# num_iter                                              16.000000
#
#                        Electronics.train_to_Electronics.train  \
# fs_same_index                                        0.914904
# fs_random_index                                      0.915408
# fs_least_index                                       0.915911
# fs_gradual_self_train                                0.910373
# num_iter                                            14.000000
#
#                        Electronics.train_to_Books.train  \
# fs_same_index                                  0.890342
# fs_random_index                                0.897384
# fs_least_index                                 0.900402
# fs_gradual_self_train                          0.918511
# num_iter                                      12.000000
#
#                        Books.train_to_Home_and_Kitchen.train  \
# fs_same_index                                       0.876636
# fs_random_index                                     0.864484
# fs_least_index                                      0.869521
# fs_gradual_self_train                               0.891742
# num_iter                                           15.000000
#
#                        Books.train_to_Movies_and_TV.train  \
# fs_same_index                                    0.909228
# fs_random_index                                  0.903177
# fs_least_index                                   0.913767
# fs_gradual_self_train                            0.913767
# num_iter                                        17.000000
#
#                        Books.train_to_Electronics.train  \
# fs_same_index                                  0.847936
# fs_random_index                                0.812185
# fs_least_index                                 0.859013
# fs_gradual_self_train                          0.882175
# num_iter                                      14.000000
#
#                        Books.train_to_Books.train
# fs_same_index                            0.941147
# fs_random_index                          0.941147
# fs_least_index                           0.943159
# fs_gradual_self_train                    0.939638
# num_iter                                12.000000
